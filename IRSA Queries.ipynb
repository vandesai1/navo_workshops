# %% [markdown]
# # Simple Image Access 2

# %% [markdown]
# # Search the WISE Database for observations of interacting galaxies.

# %%
import requests
from astropy.io.votable.tree import VOTableFile, Resource, Table, Field

# %%
votable = requests.get("https://irsa.ipac.caltech.edu/SIA?COLLECTION=wise_allwise&POS=circle+-164.7+-5.8+0.002777")

# %%
r.status_code
# Out:
# 200

# %%
print(votable.url)
# Out:
# https://irsa.ipac.caltech.edu/SIA?COLLECTION=wise_allwise&POS=circle+-164.7+-5.8+0.002777

# %%
print(votable.text)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <VOTABLE version="1.3" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.ivoa.net/xml/VOTable/v1.3" xmlns:stc="http://www.ivoa.net/xml/STC/v1.30">
#   <RESOURCE type="results">
#     <INFO name="QUERY_STATUS" value="OK"/>
#     <TABLE>
#       <FIELD name="s_region" datatype="char" arraysize="*" ucd="phys.angArea;obs" unit="deg" utype="obscore:char.spatialaxis.coverage.support.area">
#         <DESCRIPTION>AstroCoordArea Region covered in STC</DESCRIPTION>
#       </FIELD>
#       <FIELD name="obs_collection" datatype="char" arraysize="*" ucd="meta.id" utype="obscore:dataid.collection">
#         <DESCRIPTION>Data collection this observation belongs to</DESCRIPTION>
#       </FIELD>
#       <FIELD name="obs_intent" datatype="char" arraysize="*" utype="caom2:ObservationIntentType">
#         <DESCRIPTION>Intended purpose of data (one of: science, calibration)</DESCRIPTION>
#       </FIELD>
# ...

# %%
table = Table(votable)

# %% [markdown]
# Table Access Protocol
